# %% [markdown]
# # Scraping New York Lobbying Data on TREES Act

# %%
from bs4 import BeautifulSoup

# %%
from playwright.async_api import async_playwright

# %%
import os

playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)

# %%
page = await browser.new_page()

# %%
await page.goto("https://reports.ethics.ny.gov/publicquery/")
# Out:
# <Response url='https://reports.ethics.ny.gov/publicquery/' request=<Request url='https://reports.ethics.ny.gov/publicquery/' method='GET'>>

# %%
await page.click("#btnSearchLobbyingFocuses")

# %%
await page.click("#btnStateActivities")

# %%
await page.click("#sbilid")

# %%
await page.fill("#tbSearchInput", "S8898")

# %%
await page.click("#btnSearch")

# %%
await page.wait_for_selector('select[name="gvResultsLob_length"]')
# Out:
# <JSHandle preview=JSHandle@node>

# %%
await page.select_option('select[name="gvResultsLob_length"]', value="99999999")
# Out:
# ['99999999']

# %%
html = await page.content()

# %%
soup_doc = BeautifulSoup(html)

# %%
filings = soup_doc.find(id='gvResultsLob').find_all('tr')[1:]

# %%
len(filings)
# Out:
# 25

# %%
filings_list = []

for filing in filings: 
    filing_type = filing.find_all('td')[1].text
    filing_period = filing.find_all('td')[2].text
    principal_lobbyist = filing.find_all('td')[6].find('a').text
    link = filing.find_all('td')[9].find('a')['href']
    url = f'https://reports.ethics.ny.gov{link}'
    await page.goto(url)

    lobby_dict = {}
    if filing_type == 'BI-MONTHLY':
        await page.click('a[data-toggle="collapse"][href="#bimotable"]')
        await page.click('a[href^="/publicquery/ViewFiling/BIMO/"]')
        html = await page.content()
        soup_doc = BeautifulSoup(html)
        lobbyists = soup_doc.find(id='FormSummaryHeaderDetails').find(class_='form-summary-header-people').find_all('div')
        principal_lobbyist_name = lobbyists[0].div.strong.text
        principal_lobbyist_address = lobbyists[0].div.address.text
        contractual_client_name = lobbyists[1].strong.text
        contractual_client_address = lobbyists[1].address.text
        beneficial_clients_name = lobbyists[2].strong.text
        beneficial_clients_address = lobbyists[2].address.text
        
        indiv_lobbyists = soup_doc.find(class_='col-lg-10').find(class_='pad-left').tbody.find_all('tr')
        num_lobbyists = len(indiv_lobbyists)

        expenses = soup_doc.find('label', string="COMPENSATION (CURRENT PERIOD ONLY)")
        compensation = expenses.parent.span.text

        total_expenses = soup_doc.find('small', string="(total of all expense categories)").parent.parent.span.text

        bills = soup_doc.find('table', id='tbPartiesLobbied').tbody.find_all('tr')
        num_bills = len(bills)


        lobby_dict['filing_type'] = filing_type
        lobby_dict['filing_period'] = filing_period
        lobby_dict['principal_lobbyist_name'] = principal_lobbyist_name
        lobby_dict['principal_lobbyist_address'] = principal_lobbyist_address
        lobby_dict['contractual_client_name'] = contractual_client_name
        lobby_dict['contractual_client_address'] = contractual_client_address
        lobby_dict['beneficial_clients_name'] = beneficial_clients_name
        lobby_dict['beneficial_clients_address'] = beneficial_clients_address
        lobby_dict['num_lobbyists'] = num_lobbyists
        lobby_dict['compensation'] = compensation
        lobby_dict['total_expenses'] = total_expenses
        lobby_dict['num_bills'] = num_bills

        filings_list.append(lobby_dict)

        

    # if filing_type == 'CLIENT SEMI-ANNUAL AMENDMENT':
    #     await page.click('a[data-toggle="collapse"][href="#csatable"]')
    #     await page.click('a[href^="/publicquery/ViewFiling/CSA/"]')
    #     await page.click('a[href="#amendList"]')
    #     html = await page.content()
    #     soup_doc = BeautifulSoup(html)
    #     lobbyists = soup_doc.find(id='FormSummaryHeaderDetails').find(class_='form-summary-header-people').find_all('div')
    #     principal_lobbyist_name = lobbyists[0].div.strong.text
    #     principal_lobbyist_address = lobbyists[0].div.address.text
    #     contractual_client_name = lobbyists[1].strong.text
    #     contractual_client_address = lobbyists[1].address.text
    #     print(contractual_client_address)
    #     beneficial_clients_name = lobbyists[2].strong.text
    #     beneficial_clients_address = lobbyists[2].strong.next.text
        
        

    #if filing_type == 'PUBLIC CORPORATION BI-MONTHLY':




        

#filings_list

        #expenses = soup_doc.find(class_='cardbox').find_all('div', class_='pad-left')
        #print(expenses)
        #compensation = expenses.div.div.p.text
        #.span.text
        #print(compensation)

# %%
filings_list
# Out:
# [{'filing_type': 'BI-MONTHLY',
#   'filing_period': 'JULY/AUGUST',
#   'principal_lobbyist_name': 'ASSOCIATION OF COUNTIES AND ITS AFFILIATED ORGANIZATIONS (NYS)',
#   'principal_lobbyist_address': '\n                                515 BROADWAYSUITE 402ALBANY, NY 12207\n\n                                \np.518-465-1473\n                                    x.225                                \n',
#   'contractual_client_name': 'ASSOCIATION OF COUNTIES AND ITS AFFILIATED ORGANIZATIONS (NYS)',
#   'contractual_client_address': '\n                                515 BROADWAYSUITE 402ALBANY, NY 12207\n\n                                \np.518-465-1473\n                                    x.225                                \n',
#   'beneficial_clients_name': 'ASSOCIATION OF COUNTIES AND ITS AFFILIATED ORGANIZATIONS (NYS)',
#   'beneficial_clients_address': '\n                                    515 BROADWAYSUITE 402ALBANY, NY 12207\n                                    \np.518-465-1473\n                                        x.225\n                                ',
#   'num_lobbyists': 6,
#   'compensation': '$4706',
#   'total_expenses': '$5580',
#   'num_bills': 22},
#  {'filing_type': 'BI-MONTHLY',
#   'filing_period': 'MARCH/APRIL',
#   'principal_lobbyist_name': 'BOLTON-ST. JOHNS, LLC',
#   'principal_lobbyist_address': '\n                                146 STATE STREETALBANY, NY 12207\n\n                                \np.518-462-4620\n                                \n',
#   'contractual_client_name': 'BOLTON-ST. JOHNS, LLC',
#   'contractual_client_address': '\n                                146 STATE STREETALBANY, NY 12207\n\n                                \np.518-462-4620\n                                \n',
#   'beneficial_clients_name': 'FRIENDS OF THE EARTH (ACTION), INC.',
#   'beneficial_clients_address': '\n                                    1101 15TH STREET NWSTE 1100WASHINGTON, DC 20005-5002\n                                    \np.202-222-0714\n\n                                ',
#   'num_lobbyists': 43,
#   'compensation': '$10000',
#   'total_expenses': '$150',
#   'num_bills': 2},
#  {'filing_type': 'BI-MONTHLY',
#   'filing_period': 'JULY/AUGUST',
#   'principal_lobbyist_name': 'CHARTER COMMUNICATIONS OPERATING, LLC',
#   'principal_lobbyist_address': '\n                                120 EAST 23RD STREET7TH FLOORNEW YORK, NY 10010\n\n                                \np.212-598-3417\n                                \n',
#   'contractual_client_name': 'CHARTER COMMUNICATIONS OPERATING, LLC',
#   'contractual_client_address': '\n                                120 EAST 23RD STREET7TH FLOORNEW YORK, NY 10010\n\n                                \np.212-598-3417\n                                \n',
#   'beneficial_clients_name': 'CHARTER COMMUNICATIONS OPERATING, LLC',
#   'beneficial_clients_address': '\n                                    120 EAST 23RD STREET7TH FLOORNEW YORK, NY 10010\n                                    \np.212-598-3417\n\n                                ',
#   'num_lobbyists': 7,
#   'compensation': '$16636',
#   'total_expenses': '$4159',
#   'num_bills': 18},
#  {'filing_type': 'BI-MONTHLY',
#   'filing_period': 'JULY/AUGUST',
#   'principal_lobbyist_name': 'DICKINSON & AVELLA, PLLC.',
#   'principal_lobbyist_address': '\n                                111 WASHINGTON AVENUESUITE 702ALBANY, NY 12210\n\n                                \np.518-599-0579\n                                \n',
#   'contractual_client_name': 'DICKINSON & AVELLA, PLLC.',
#   'contractual_client_address': '\n                                111 WASHINGTON AVENUESUITE 702ALBANY, NY 12210\n\n                                \np.518-599-0579\n                                \n',
#   'beneficial_clients_name': 'VERIZON',
#   'beneficial_clients_address': '\n                                    140 WEST STREETNEW YORK, NY 10007\n                                    \np.518-396-1086\n\n                                ',
#   'num_lobbyists': 4,
#   'compensation': '$16666',
#   'total_expenses': '$193',
#   'num_bills': 12},
#  {'filing_type': 'BI-MONTHLY',
#   'filing_period': 'SEPTEMBER/OCTOBER',
#   'principal_lobbyist_name': 'ENVIRONMENTAL ADVOCATES ACTION, INC',
#   'principal_lobbyist_address': '\n                                353 HAMILTON STREETALBANY, NY 12210\n\n                                \np.518-462-5526\n                                \n',
#   'contractual_client_name': 'ENVIRONMENTAL ADVOCATES ACTION, INC',
#   'contractual_client_address': '\n                                353 HAMILTON STREETALBANY, NY 12210\n\n                                \np.518-462-5526\n                                \n',
#   'beneficial_clients_name': 'ENVIRONMENTAL ADVOCATES ACTION, INC',
#   'beneficial_clients_address': '\n                                    353 HAMILTON STREETALBANY, NY 12210\n                                    \np.518-462-5526\n\n                                ',
#   'num_lobbyists': 2,
#   'compensation': '$2066',
#   'total_expenses': '$500',
#   'num_bills': 73},
#  {'filing_type': 'BI-MONTHLY',
#   'filing_period': 'NOVEMBER/DECEMBER',
#   'principal_lobbyist_name': 'ENVIRONMENTAL ADVOCATES ACTION, INC',
#   'principal_lobbyist_address': '\n                                353 HAMILTON STREETALBANY, NY 12210\n\n                                \np.518-462-5526\n                                \n',
#   'contractual_client_name': 'ENVIRONMENTAL ADVOCATES ACTION, INC',
#   'contractual_client_address': '\n                                353 HAMILTON STREETALBANY, NY 12210\n\n                                \np.518-462-5526\n                                \n',
#   'beneficial_clients_name': 'ENVIRONMENTAL ADVOCATES ACTION, INC',
#   'beneficial_clients_address': '\n                                    353 HAMILTON STREETALBANY, NY 12210\n                                    \np.518-462-5526\n\n                                ',
#   'num_lobbyists': 2,
#   'compensation': '$2066',
#   'total_expenses': '$500',
#   'num_bills': 73},
#  {'filing_type': 'BI-MONTHLY',
#   'filing_period': 'MARCH/APRIL',
#   'principal_lobbyist_name': 'ENVIRONMENTAL ADVOCATES NY, INC',
#   'principal_lobbyist_address': '\n                                353 HAMILTON STALBANY, NY 12210\n\n                                \np.518-462-5526\n                                \n',
#   'contractual_client_name': 'ENVIRONMENTAL ADVOCATES NY, INC',
#   'contractual_client_address': '\n                                353 HAMILTON STALBANY, NY 12210\n\n                                \np.518-462-5526\n                                \n',
#   'beneficial_clients_name': 'ENVIRONMENTAL ADVOCATES NY, INC',
#   'beneficial_clients_address': '\n                                    353 HAMILTON STALBANY, NY 12210\n                                    \np.518-462-5526\n\n                                ',
#   'num_lobbyists': 8,
#   'compensation': '$6886',
#   'total_expenses': '$1496',
#   'num_bills': 105},
#  {'filing_type': 'BI-MONTHLY',
#   'filing_period': 'MAY/JUNE',
#   'principal_lobbyist_name': 'ENVIRONMENTAL ADVOCATES NY, INC',
#   'principal_lobbyist_address': '\n                                353 HAMILTON STALBANY, NY 12210\n\n                                \np.518-462-5526\n                                \n',
#   'contractual_client_name': 'ENVIRONMENTAL ADVOCATES NY, INC',
#   'contractual_client_address': '\n                                353 HAMILTON STALBANY, NY 12210\n\n                                \np.518-462-5526\n                                \n',
#   'beneficial_clients_name': 'ENVIRONMENTAL ADVOCATES NY, INC',
#   'beneficial_clients_address': '\n                                    353 HAMILTON STALBANY, NY 12210\n                                    \np.518-462-5526\n\n                                ',
#   'num_lobbyists': 8,
#   'compensation': '$6886',
#   'total_expenses': '$1496',
#   'num_bills': 105},
#  {'filing_type': 'BI-MONTHLY',
#   'filing_period': 'JULY/AUGUST',
#   'principal_lobbyist_name': 'ENVIRONMENTAL ADVOCATES NY, INC',
#   'principal_lobbyist_address': '\n                                353 HAMILTON STALBANY, NY 12210\n\n                                \np.518-462-5526\n                                \n',
#   'contractual_client_name': 'ENVIRONMENTAL ADVOCATES NY, INC',
#   'contractual_client_address': '\n                                353 HAMILTON STALBANY, NY 12210\n\n                                \np.518-462-5526\n                                \n',
#   'beneficial_clients_name': 'ENVIRONMENTAL ADVOCATES NY, INC',
#   'beneficial_clients_address': '\n                                    353 HAMILTON STALBANY, NY 12210\n                                    \np.518-462-5526\n\n                                ',
#   'num_lobbyists': 8,
#   'compensation': '$6886',
#   'total_expenses': '$1496',
#   'num_bills': 105},
#  {'filing_type': 'BI-MONTHLY',
#   'filing_period': 'SEPTEMBER/OCTOBER',
#   'principal_lobbyist_name': 'ENVIRONMENTAL ADVOCATES NY, INC',
#   'principal_lobbyist_address': '\n                                353 HAMILTON STALBANY, NY 12210\n\n                                \np.518-462-5526\n                                \n',
#   'contractual_client_name': 'ENVIRONMENTAL ADVOCATES NY, INC',
#   'contractual_client_address': '\n                                353 HAMILTON STALBANY, NY 12210\n\n                                \np.518-462-5526\n                                \n',
#   'beneficial_clients_name': 'ENVIRONMENTAL ADVOCATES NY, INC',
#   'beneficial_clients_address': '\n                                    353 HAMILTON STALBANY, NY 12210\n                                    \np.518-462-5526\n\n                                ',
#   'num_lobbyists': 8,
#   'compensation': '$6886',
#   'total_expenses': '$1496',
#   'num_bills': 105},
#  {'filing_type': 'BI-MONTHLY',
#   'filing_period': 'MARCH/APRIL',
#   'principal_lobbyist_name': 'FRIENDS OF THE EARTH',
#   'principal_lobbyist_address': '\n                                1101 15TH STREET NWSTE 1100WASHINGTON, DC 20005-5002\n\n                                \np.202-222-0714\n                                \n',
#   'contractual_client_name': 'FRIENDS OF THE EARTH',
#   'contractual_client_address': '\n                                1101 15TH STREET NWSTE 1100WASHINGTON, DC 20005-5002\n\n                                \np.202-222-0714\n                                \n',
#   'beneficial_clients_name': 'FRIENDS OF THE EARTH',
#   'beneficial_clients_address': '\n                                    1101 15TH STREET NWSTE 1100WASHINGTON, DC 20005-5002\n                                    \np.202-222-0714\n\n                                ',
#   'num_lobbyists': 1,
#   'compensation': '$306',
#   'total_expenses': '$816',
#   'num_bills': 2},
#  {'filing_type': 'BI-MONTHLY',
#   'filing_period': 'MAY/JUNE',
#   'principal_lobbyist_name': 'FRIENDS OF THE EARTH',
#   'principal_lobbyist_address': '\n                                1101 15TH STREET NWSTE 1100WASHINGTON, DC 20005-5002\n\n                                \np.202-222-0714\n                                \n',
#   'contractual_client_name': 'FRIENDS OF THE EARTH',
#   'contractual_client_address': '\n                                1101 15TH STREET NWSTE 1100WASHINGTON, DC 20005-5002\n\n                                \np.202-222-0714\n                                \n',
#   'beneficial_clients_name': 'FRIENDS OF THE EARTH',
#   'beneficial_clients_address': '\n                                    1101 15TH STREET NWSTE 1100WASHINGTON, DC 20005-5002\n                                    \np.202-222-0714\n\n                                ',
#   'num_lobbyists': 1,
#   'compensation': '$306',
#   'total_expenses': '$816',
#   'num_bills': 2}]

# %%
import pandas as pd

df = pd.DataFrame(filings_list)

# %%
df
# Out:
#    filing_type      filing_period  \
# 0   BI-MONTHLY        JULY/AUGUST
# 1   BI-MONTHLY        MARCH/APRIL
# 2   BI-MONTHLY        JULY/AUGUST
# 3   BI-MONTHLY        JULY/AUGUST
# 4   BI-MONTHLY  SEPTEMBER/OCTOBER
# 5   BI-MONTHLY  NOVEMBER/DECEMBER
# 6   BI-MONTHLY        MARCH/APRIL
# 7   BI-MONTHLY           MAY/JUNE
# 8   BI-MONTHLY        JULY/AUGUST
# 9   BI-MONTHLY  SEPTEMBER/OCTOBER
# 10  BI-MONTHLY        MARCH/APRIL
# 11  BI-MONTHLY           MAY/JUNE
#
#                               principal_lobbyist_name  \
# 0   ASSOCIATION OF COUNTIES AND ITS AFFILIATED ORG...
# 1                               BOLTON-ST. JOHNS, LLC
# 2               CHARTER COMMUNICATIONS OPERATING, LLC
# 3                           DICKINSON & AVELLA, PLLC.
# 4                 ENVIRONMENTAL ADVOCATES ACTION, INC
# 5                 ENVIRONMENTAL ADVOCATES ACTION, INC
# 6                     ENVIRONMENTAL ADVOCATES NY, INC
# 7                     ENVIRONMENTAL ADVOCATES NY, INC
# 8                     ENVIRONMENTAL ADVOCATES NY, INC
# 9                     ENVIRONMENTAL ADVOCATES NY, INC
# 10                               FRIENDS OF THE EARTH
# 11                               FRIENDS OF THE EARTH
#
#                            principal_lobbyist_address  \
# 0   \n                                515 BROADWAY...
# 1   \n                                146 STATE ST...
# 2   \n                                120 EAST 23R...
# 3   \n                                111 WASHINGT...
# 4   \n                                353 HAMILTON...
# 5   \n                                353 HAMILTON...
# 6   \n                                353 HAMILTON...
# 7   \n                                353 HAMILTON...
# 8   \n                                353 HAMILTON...
# 9   \n                                353 HAMILTON...
# 10  \n                                1101 15TH ST...
# 11  \n                                1101 15TH ST...
#
#                               contractual_client_name  \
# 0   ASSOCIATION OF COUNTIES AND ITS AFFILIATED ORG...
# 1                               BOLTON-ST. JOHNS, LLC
# 2               CHARTER COMMUNICATIONS OPERATING, LLC
# 3                           DICKINSON & AVELLA, PLLC.
# 4                 ENVIRONMENTAL ADVOCATES ACTION, INC
# 5                 ENVIRONMENTAL ADVOCATES ACTION, INC
# 6                     ENVIRONMENTAL ADVOCATES NY, INC
# 7                     ENVIRONMENTAL ADVOCATES NY, INC
# 8                     ENVIRONMENTAL ADVOCATES NY, INC
# 9                     ENVIRONMENTAL ADVOCATES NY, INC
# 10                               FRIENDS OF THE EARTH
# 11                               FRIENDS OF THE EARTH
#
#                            contractual_client_address  \
# 0   \n                                515 BROADWAY...
# 1   \n                                146 STATE ST...
# 2   \n                                120 EAST 23R...
# 3   \n                                111 WASHINGT...
# 4   \n                                353 HAMILTON...
# 5   \n                                353 HAMILTON...
# 6   \n                                353 HAMILTON...
# 7   \n                                353 HAMILTON...
# 8   \n                                353 HAMILTON...
# 9   \n                                353 HAMILTON...
# 10  \n                                1101 15TH ST...
# 11  \n                                1101 15TH ST...
#
#                               beneficial_clients_name  \
# 0   ASSOCIATION OF COUNTIES AND ITS AFFILIATED ORG...
# 1                 FRIENDS OF THE EARTH (ACTION), INC.
# 2               CHARTER COMMUNICATIONS OPERATING, LLC
# 3                                             VERIZON
# 4                 ENVIRONMENTAL ADVOCATES ACTION, INC
# 5                 ENVIRONMENTAL ADVOCATES ACTION, INC
# 6                     ENVIRONMENTAL ADVOCATES NY, INC
# 7                     ENVIRONMENTAL ADVOCATES NY, INC
# 8                     ENVIRONMENTAL ADVOCATES NY, INC
# 9                     ENVIRONMENTAL ADVOCATES NY, INC
# 10                               FRIENDS OF THE EARTH
# 11                               FRIENDS OF THE EARTH
#
#                            beneficial_clients_address  num_lobbyists  \
# 0   \n                                    515 BROA...              6
# 1   \n                                    1101 15T...             43
# 2   \n                                    120 EAST...              7
# 3   \n                                    140 WEST...              4
# 4   \n                                    353 HAMI...              2
# 5   \n                                    353 HAMI...              2
# 6   \n                                    353 HAMI...              8
# 7   \n                                    353 HAMI...              8
# 8   \n                                    353 HAMI...              8
# 9   \n                                    353 HAMI...              8
# 10  \n                                    1101 15T...              1
# 11  \n                                    1101 15T...              1
#
#    compensation total_expenses  num_bills
# 0         $4706          $5580         22
# 1        $10000           $150          2
# 2        $16636          $4159         18
# 3        $16666           $193         12
# 4         $2066           $500         73
# 5         $2066           $500         73
# 6         $6886          $1496        105
# 7         $6886          $1496        105
# 8         $6886          $1496        105
# 9         $6886          $1496        105
# 10         $306           $816          2
# 11         $306           $816          2

# %%
0
